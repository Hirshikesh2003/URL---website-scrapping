# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import urllib.request,sys,time
import pandas as pd

# %%
soup = BeautifulSoup(req.content, "html.parser")

# %%
url = "https://timesofindia.indiatimes.com/?from=mdr"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',}
req = requests.get(url, headers = headers)
soup = BeautifulSoup(req.content, "html.parser")
with open( r"C:\Users\aksha\Downloads\hirshi\1.txt" ,"w",encoding="utf-8") as oFile:
    oFile.write(str(soup.get_text()))
    oFile.close()

# %%
print(soup.get_text())
# Out:
# News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India EditionININUSMon, Jan 30, 2023 | Updated 10.22AM ISTSign InTOI+Budget 2023VideosCityMetro CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther  regionmysurunagpurnashiknavi mumbainoidapatnapuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosIndiafeaturedcoronavirusopinions and featuresTimes EvokeMaharashtraDelhiKarnatakaTamil NaduTelanganaUttar PradeshWest BengalGujaratMadhya PradeshBiharChandigarhRajasthanArunachal PradeshAndhra PradeshAssamChhattisgarhGoaHaryanaHimachal PradeshJammu KashmirJhark
# ...

# %%
res = soup.title
print(res.get_text())
# Out:
# News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    News - Latest News, Breaking News, Bollywood, Sports, Business and Political News | Times of India
#   </title>
#   <meta content="Top News in India: Read Latest News on Sports, Business, Entertainment, Blogs and Opinions from leading columnists. Times of India brings the Breaking News and Latest News Headlines from India and around the World." name="description"/>
#   <meta content="News, Breaking news, Latest news, Live news, Today news, News Today, India news, English news, Politics news, Top news in India" name="keywords"/>
#   <link href="https://timesofindia.indiatimes.com/" rel="canonical"/>
#   <link href="https://timesofindia.indiatimes.com/us" hreflang="en-us" rel="alternate"/>
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aksha\AppData\Roaming\nltk_data...
# ...

# %%
import io
#from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('english')) 
file1 = open(r"C:\Users\aksha\Downloads\hirshi\1.txt")# ,encoding="utf-8")

# %%
line = file1.read()
words = line.split() 
for r in words: 
    if not r in stop_words: 
        appendFile = open(r"C:\Users\aksha\Downloads\hirshi\1.txt",'a', encoding="utf-8") 
        appendFile.write(" "+r)

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemma = WordNetLemmatizer()

# %%
file1 = open(r"C:\Users\aksha\Downloads\hirshi\1.txt")# ,encoding="utf-8") 
line = file1.read()
words = line.split()

# %%
words
# Out:
# ['News',
#  '-',
#  'Latest',
#  'News,',
#  'Breaking',
#  'News,',
#  'Bollywood,',
#  'Sports,',
#  'Business',
#  'and',
#  'Political',
#  'News',
#  '|',
#  'Times',
#  'of',
#  'India',
#  'EditionININUSMon,',
#  'Jan',
#  '30,',
#  '2023',
#  '|',
#  'Updated',
#  '10.26AM',
#  'ISTSign',
#  'InTOI+Budget',
#  '2023VideosCityMetro',
#  'CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther',
#  '',
#  'regionmysurunagpurnashiknavi',
#  'mumbainoidapatnapuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosIndiafeaturedcoronavirusopinions',
#  'and',
#  'featuresTimes',
# ...
